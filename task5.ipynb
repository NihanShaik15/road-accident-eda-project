# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b8f82d7-4d3a-4a03-9e07-860f0706aca8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b8f82d7-4d3a-4a03-9e07-860f0706aca8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("cleaned_road_accidents.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape: (20000, 26)
#
# Columns:
# Index(['accident_id', 'city', 'state', 'latitude', 'longitude', 'date', 'time',
#        'hour', 'day_of_week', 'is_weekend', 'road_type', 'lanes',
#        'traffic_signal', 'weather', 'visibility', 'temperature',
#        'traffic_density', 'cause', 'accident_severity', 'vehicles_involved',
#        'casualties', 'is_peak_hour', 'festival', 'risk_score', 'year',
#        'month'],
#       dtype='object')
#
# Missing Values:
# accident_id              0
# city                     0
# state                    0
# latitude                 0
# longitude                0
# date                     0
# time                     0
# hour                     0
# day_of_week              0
# is_weekend               0
# road_type                0
# lanes                    0
# traffic_signal           0
# weather                  0
# visibility               0
# temperature              0
# traffic_density          0
# cause                    0
# ...

# %%
print(df.describe())
# Out:
#         accident_id      latitude     longitude          hour    is_weekend  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean    9999.500000     20.389207     78.173330     11.487200      0.286150
# std     5773.647028      6.165791      4.485967      6.945563      0.451972
# min        0.000000     12.800172     72.700017      0.000000      0.000000
# 25%     4999.750000     13.198653     73.997979      5.000000      0.000000
# 50%     9999.500000     18.812008     77.297000     12.000000      0.000000
# 75%    14999.250000     28.402467     80.111089     18.000000      1.000000
# max    19999.000000     30.799960     88.499861     23.000000      1.000000
#
#               lanes  traffic_signal   temperature  vehicles_involved  \
# count  20000.000000    20000.000000  20000.000000       20000.000000
# mean       3.493950        0.499850     27.579600           2.992000
# std        1.705406        0.500012      7.454746           1.415534
# ...

# %%
print("========== PROJECT SUMMARY ==========")

print("✔ Data Cleaning Completed")
print("✔ SQL Analysis Completed")
print("✔ Power BI Dashboard Created")
print("✔ Machine Learning Model Developed")

print("\nKey Insights")

print("- Accident-prone cities identified.")
print("- Weather impacts analyzed.")
print("- Traffic density patterns studied.")
print("- Accident severity prediction completed.")
# Out:
# ========== PROJECT SUMMARY ==========
# ✔ Data Cleaning Completed
# ✔ SQL Analysis Completed
# ✔ Power BI Dashboard Created
# ✔ Machine Learning Model Developed
#
# Key Insights
# - Accident-prone cities identified.
# - Weather impacts analyzed.
# - Traffic density patterns studied.
# - Accident severity prediction completed.

# %%
df.to_csv("final_road_accident_dataset.csv", index=False)

print("Final Dataset Saved Successfully")
# Out:
# Final Dataset Saved Successfully

# %%
print("""
==========================================
ROAD ACCIDENT ANALYTICS PROJECT
==========================================

Project Completed Successfully

Modules Completed

Task 1 : Data Cleaning & EDA
Task 2 : SQL Analysis
Task 3 : Power BI Dashboard
Task 4 : Machine Learning
Task 5 : Documentation & Presentation

==========================================
""")
# Out:
# ...
# ROAD ACCIDENT ANALYTICS PROJECT
# ...
#
# Project Completed Successfully
#
# Modules Completed
#
# Task 1 : Data Cleaning & EDA
# Task 2 : SQL Analysis
# Task 3 : Power BI Dashboard
# Task 4 : Machine Learning
# Task 5 : Documentation & Presentation
#
# ...
